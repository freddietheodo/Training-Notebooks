# %% [markdown]
# ##### Hidden Functions:

# %%
import pandas as pd
import spotipy
import sys
from spotipy.oauth2 import SpotifyClientCredentials
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
from dotenv import load_dotenv
import os

# Used to access my .env variables so I dont leak them
load_dotenv()

# Create a spotify client:
client_id = os.environ.get("SPOTIFY_CLIENT_ID")
client_secret = os.environ.get("SPOTIFY_CLIENT_SECRET")

spotify = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id,
                                                                client_secret=client_secret))

# %%
def get_playlist_track_ids(spotify, playlist_id, offset=0):
    df = pd.DataFrame(spotify.playlist_tracks(playlist_id, offset=offset))
    tracks = df['items']

    track_ids = []
    for row in tracks:
        track_ids.append(row['track']['id'])
    return track_ids

# %%
def get_audio_features(spotify, track_ids):
    track_audio_features = spotify.audio_features(track_ids)
    return (pd.DataFrame(track_audio_features))

# %%
whale_track_ids = whale_track_ids = get_playlist_track_ids(spotify, "5v0XNgUfSqaDSZ6SkJkN7E")
whale_audio_features = get_audio_features(spotify, whale_track_ids)

# %%
test_playlist_audio_features_list = []

#Because the spotify limit is set to 100 results, we loop through 4 times to get 400 results
for offset in [0,100,200,300]:
     test_tracks_ids = get_playlist_track_ids(spotify, "2Vjg4BQi0ILYyEN5lr9Lma",offset=offset)
     test_audio_features = get_audio_features(spotify, test_tracks_ids)
     test_playlist_audio_features_list.append(test_audio_features)

#Merge all the dataframes into one big one :)
test_playlist_audio_features = pd.concat(test_playlist_audio_features_list, ignore_index=True)

# %% [markdown]
# <img src="https://media.giphy.com/media/sVnKj2wDhUTsFKFWhx/giphy.gif" alt ="Office Gif" style="height:250px"/>
#
# <br>
# <br>
#
# #  🎉🎉🎉 Creating a spotify recommendation system 🎉🎉🎉

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ###  Step 1) Gathering a dataset
#
# - Needs have enough values to break the cold start up problem.
# - Needs to include song meta data so we can use content based filtering.
# - Needs to be small enough so the model does not take over 1 minute to run.
# - Needs to include enough variation to prove that the recommendation system is actually working!
#
# ![Forgaing](https://media.giphy.com/media/3oriO5oRIGNYdFFuXm/giphy.gif)

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ##### [Freddie's Playlist](https://open.spotify.com/playlist/5v0XNgUfSqaDSZ6SkJkN7E?si=a3cc7f0fe7bc424b)
#
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/playlist/5v0XNgUfSqaDSZ6SkJkN7E?utm_source=generator&theme=0" width="100%" height="352" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>
#
# Features:
# - 73 songs
# - Freddie's depression playlist!

# %% [markdown]
# <hr>

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ##### [Test Playlist](https://open.spotify.com/playlist/2Vjg4BQi0ILYyEN5lr9Lma?si=eaf02cfa5b364f24)

# %% [markdown]
# **400 songs (mixture of random and non-random)**
#
# - This generated through adding 100 spotify recommended songs.
# - Then adding random songs to introduce variablility from: Theodo Playlist, A Super John Mcginn playlist, drum and base playlist, Classical Bangers, Eminem albums.
#
# <img src="./images/random-playlist.png" alt="random-songs" style="margin:30px; height:200px; width:500px;"/>

# %% [markdown]
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/playlist/2Vjg4BQi0ILYyEN5lr9Lma?utm_source=generator&theme=0" width="100%" height="352" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>

# %% [markdown]
# <hr>

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# <hr>
#
# ###  Step 2) Extract Track Meta Data
# - We need to be able to use the meta data in code.
#
#
# <div style="width:480px"><iframe allow="fullscreen" frameBorder="0" height="270" src="https://giphy.com/embed/lu01tsQqf1mJuHrFVq/video" width="480"></iframe></div>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# **Step 2.1) Connect to the [Spotify Api](https://developer.spotify.com/documentation/web-api)**

# %%
spotify = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id,
                                                                client_secret=client_secret))

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ##### **Step 2.2) Get playlist tracks**

# %%
playlist_id = "5v0XNgUfSqaDSZ6SkJkN7E"

# Searches for my playlist, and stores in it a data frame (A nice table)
df = pd.DataFrame(spotify.playlist_tracks(playlist_id)["items"])

df.head(5)
# Out:
#                added_at                                           added_by  \
# 0  2022-01-02T19:41:08Z  {'external_urls': {'spotify': 'https://open.sp...
# 1  2022-12-09T11:20:50Z  {'external_urls': {'spotify': 'https://open.sp...
# 2  2022-12-09T11:25:33Z  {'external_urls': {'spotify': 'https://open.sp...
# 3  2022-12-09T11:25:32Z  {'external_urls': {'spotify': 'https://open.sp...
# 4  2022-12-09T11:28:27Z  {'external_urls': {'spotify': 'https://open.sp...
#
#    is_local primary_color                                              track  \
# 0     False          None  {'album': {'album_type': 'album', 'artists': [...
# 1     False          None  {'album': {'album_type': 'single', 'artists': ...
# 2     False          None  {'album': {'album_type': 'album', 'artists': [...
# 3     False          None  {'album': {'album_type': 'album', 'artists': [...
# 4     False          None  {'album': {'album_type': 'album', 'artists': [...
#
#   video_thumbnail
# 0   {'url': None}
# 1   {'url': None}
# 2   {'url': None}
# 3   {'url': None}
# 4   {'url': None}

# %% [markdown]
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# #### **Step 2.3) Get track audio features**

# %%
track_id = "3CAX47TnPqTujLIQTw8nwI"

# Searches for my playlist, and stores in it a data frame (A nice table)
df = pd.DataFrame(spotify.audio_features(track_id))
df.head(5)
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.401   0.364    5   -10.836     1        0.033          0.45
#
#    instrumentalness  liveness  valence   tempo            type  \
# 0            0.0503     0.162    0.224  129.57  audio_features
#
#                        id                                   uri  \
# 0  3CAX47TnPqTujLIQTw8nwI  spotify:track:3CAX47TnPqTujLIQTw8nwI
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3CAX47TnPqTu...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3CAX...       328507
#
#    time_signature
# 0               4

# %% [markdown]
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/3CAX47TnPqTujLIQTw8nwI?utm_source=generator" width="100%" height="152" frameBorder="0" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
#
# ##### Once you combine your functions (See hidden code folder for how I do that) you get two dataframes:

# %% [markdown]
# ##### **Whale:**

# %%
whale_audio_features
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.401  0.3640    5   -10.836     1       0.0330        0.4500
# 1          0.493  0.3720    7   -11.889     1       0.0331        0.9640
# 2          0.386  0.2050    4   -16.699     1       0.0366        0.6530
# 3          0.556  0.2690    5   -12.234     1       0.0502        0.9460
# 4          0.489  0.2500    9   -12.766     1       0.0307        0.9210
# ..           ...     ...  ...       ...   ...          ...           ...
# 68         0.577  0.4340    7    -8.437     1       0.0303        0.8870
# 69         0.509  0.3100    9   -10.623     1       0.0313        0.9590
# 70         0.412  0.2270    0   -12.696     1       0.0359        0.7870
# 71         0.370  0.4670    5    -9.013     1       0.0273        0.0205
# 72         0.286  0.0847    2    -9.883     1       0.0397        0.9340
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.050300    0.1620   0.2240  129.570  audio_features
# 1           0.030800    0.1170   0.2500  116.860  audio_features
# 2           0.044800    0.1060   0.6230  172.373  audio_features
# 3           0.004920    0.0834   0.1730   99.902  audio_features
# 4           0.736000    0.1100   0.0562  128.286  audio_features
# ..               ...       ...      ...      ...             ...
# 68          0.215000    0.0822   0.3210   79.497  audio_features
# 69          0.229000    0.0963   0.1510  137.474  audio_features
# 70          0.000005    0.2820   0.2260   80.111  audio_features
# 71          0.572000    0.1090   0.1820   94.485  audio_features
# 72          0.000007    0.1210   0.1120   70.743  audio_features
#
#                         id                                   uri  \
# 0   3CAX47TnPqTujLIQTw8nwI  spotify:track:3CAX47TnPqTujLIQTw8nwI
# 1   15WbjBy1bzH1UsUldBwwlW  spotify:track:15WbjBy1bzH1UsUldBwwlW
# 2   6UIxGIqWlO5wsddY44AV1R  spotify:track:6UIxGIqWlO5wsddY44AV1R
# 3   2D369Iv0P8FplOVp5ZMel7  spotify:track:2D369Iv0P8FplOVp5ZMel7
# 4   5so4VqG1hJDiqyRqavbH6o  spotify:track:5so4VqG1hJDiqyRqavbH6o
# ..                     ...                                   ...
# 68  6eusWfAal7mOOLr0XFLkiY  spotify:track:6eusWfAal7mOOLr0XFLkiY
# 69  7CoMBpPTwQi2wPT0U0Nr9b  spotify:track:7CoMBpPTwQi2wPT0U0Nr9b
# 70  35r28RDot7nPE7y9K9H7l0  spotify:track:35r28RDot7nPE7y9K9H7l0
# 71  0yc6Gst2xkRu0eMLeRMGCX  spotify:track:0yc6Gst2xkRu0eMLeRMGCX
# 72  7sq2z9oX2S0CvgTqCZ0ko4  spotify:track:7sq2z9oX2S0CvgTqCZ0ko4
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/3CAX47TnPqTu...
# 1   https://api.spotify.com/v1/tracks/15WbjBy1bzH1...
# 2   https://api.spotify.com/v1/tracks/6UIxGIqWlO5w...
# 3   https://api.spotify.com/v1/tracks/2D369Iv0P8Fp...
# 4   https://api.spotify.com/v1/tracks/5so4VqG1hJDi...
# ..                                                ...
# 68  https://api.spotify.com/v1/tracks/6eusWfAal7mO...
# 69  https://api.spotify.com/v1/tracks/7CoMBpPTwQi2...
# 70  https://api.spotify.com/v1/tracks/35r28RDot7nP...
# 71  https://api.spotify.com/v1/tracks/0yc6Gst2xkRu...
# 72  https://api.spotify.com/v1/tracks/7sq2z9oX2S0C...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/3CAX...       328507
# 1   https://api.spotify.com/v1/audio-analysis/15Wb...       285160
# 2   https://api.spotify.com/v1/audio-analysis/6UIx...       152613
# 3   https://api.spotify.com/v1/audio-analysis/2D36...       273693
# 4   https://api.spotify.com/v1/audio-analysis/5so4...       316800
# ..                                                ...          ...
# 68  https://api.spotify.com/v1/audio-analysis/6eus...       178627
# 69  https://api.spotify.com/v1/audio-analysis/7CoM...       208653
# 70  https://api.spotify.com/v1/audio-analysis/35r2...       257267
# 71  https://api.spotify.com/v1/audio-analysis/0yc6...       290617
# 72  https://api.spotify.com/v1/audio-analysis/7sq2...       255987
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 68               4
# 69               3
# 70               4
# 71               4
# 72               4
#
# [73 rows x 18 columns]

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# ##### **Test Playlist:**

# %%
test_playlist_audio_features
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.401   0.364    5   -10.836     1       0.0330         0.450
# 1           0.493   0.372    7   -11.889     1       0.0331         0.964
# 2           0.386   0.205    4   -16.699     1       0.0366         0.653
# 3           0.556   0.269    5   -12.234     1       0.0502         0.946
# 4           0.489   0.250    9   -12.766     1       0.0307         0.921
# ..            ...     ...  ...       ...   ...          ...           ...
# 395         0.475   0.178    7    -9.976     1       0.0347         0.745
# 396         0.588   0.412    2   -10.669     1       0.0613         0.152
# 397         0.637   0.651    2    -7.089     1       0.0521         0.320
# 398         0.446   0.247   11   -13.036     0       0.0287         0.905
# 399         0.296   0.284   10   -14.010     0       0.0330         0.968
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.050300    0.1620   0.2240  129.570  audio_features
# 1            0.030800    0.1170   0.2500  116.860  audio_features
# 2            0.044800    0.1060   0.6230  172.373  audio_features
# 3            0.004920    0.0834   0.1730   99.902  audio_features
# 4            0.736000    0.1100   0.0562  128.286  audio_features
# ..                ...       ...      ...      ...             ...
# 395          0.000189    0.0899   0.2300  136.687  audio_features
# 396          0.000000    0.1340   0.3020  133.815  audio_features
# 397          0.000000    0.0938   0.4850  115.926  audio_features
# 398          0.233000    0.1110   0.2450  138.328  audio_features
# 399          0.189000    0.0961   0.0917  114.786  audio_features
#
#                          id                                   uri  \
# 0    3CAX47TnPqTujLIQTw8nwI  spotify:track:3CAX47TnPqTujLIQTw8nwI
# 1    15WbjBy1bzH1UsUldBwwlW  spotify:track:15WbjBy1bzH1UsUldBwwlW
# 2    6UIxGIqWlO5wsddY44AV1R  spotify:track:6UIxGIqWlO5wsddY44AV1R
# 3    2D369Iv0P8FplOVp5ZMel7  spotify:track:2D369Iv0P8FplOVp5ZMel7
# 4    5so4VqG1hJDiqyRqavbH6o  spotify:track:5so4VqG1hJDiqyRqavbH6o
# ..                      ...                                   ...
# 395  1ptwL6lZNLc654XAaHqcHb  spotify:track:1ptwL6lZNLc654XAaHqcHb
# 396  2A1FGotEDhN5UjBiLsUwnk  spotify:track:2A1FGotEDhN5UjBiLsUwnk
# 397  7ByxizhA4GgEf7Sxomxhze  spotify:track:7ByxizhA4GgEf7Sxomxhze
# 398  4x1dWc1GgAfC04GcTlllax  spotify:track:4x1dWc1GgAfC04GcTlllax
# 399  4CiqKccFFYGmFPz7HVTjfW  spotify:track:4CiqKccFFYGmFPz7HVTjfW
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/3CAX47TnPqTu...
# 1    https://api.spotify.com/v1/tracks/15WbjBy1bzH1...
# 2    https://api.spotify.com/v1/tracks/6UIxGIqWlO5w...
# 3    https://api.spotify.com/v1/tracks/2D369Iv0P8Fp...
# 4    https://api.spotify.com/v1/tracks/5so4VqG1hJDi...
# ..                                                 ...
# 395  https://api.spotify.com/v1/tracks/1ptwL6lZNLc6...
# 396  https://api.spotify.com/v1/tracks/2A1FGotEDhN5...
# 397  https://api.spotify.com/v1/tracks/7ByxizhA4GgE...
# 398  https://api.spotify.com/v1/tracks/4x1dWc1GgAfC...
# 399  https://api.spotify.com/v1/tracks/4CiqKccFFYGm...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/3CAX...       328507
# 1    https://api.spotify.com/v1/audio-analysis/15Wb...       285160
# 2    https://api.spotify.com/v1/audio-analysis/6UIx...       152613
# 3    https://api.spotify.com/v1/audio-analysis/2D36...       273693
# 4    https://api.spotify.com/v1/audio-analysis/5so4...       316800
# ..                                                 ...          ...
# 395  https://api.spotify.com/v1/audio-analysis/1ptw...       280107
# 396  https://api.spotify.com/v1/audio-analysis/2A1F...       155660
# 397  https://api.spotify.com/v1/audio-analysis/7Byx...       251511
# 398  https://api.spotify.com/v1/audio-analysis/4x1d...       106250
# 399  https://api.spotify.com/v1/audio-analysis/4Ciq...       243467
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 395               4
# 396               4
# 397               4
# 398               1
# 399               4
#
# [400 rows x 18 columns]

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <hr>
#
# ### Step 3) Start creating our Recommendation System
# - Once we have got all of our data we are able to start creating our recommendation system.
#
# <br>
# <br>
# <br>
#
#
# <iframe src="https://giphy.com/embed/SjR2HvaFokmJ1a30wR" width="480" height="270" frameBorder="0" class="giphy-embed" allowFullScreen></iframe>
#
#
# <br>
# <br>
# <br>
#
# <br>
# <br>
# <br>

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **How can we decide a metric?**
# - We want a metric that is going make songs that belong in my playlist stand out in comparison to the test dataset
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %%
whale_audio_features.describe()
# Out:
#        danceability     energy        key   loudness       mode  speechiness  \
# count     73.000000  73.000000  73.000000  73.000000  73.000000    73.000000
# mean       0.502274   0.398518   5.027397 -10.311479   0.753425     0.045911
# std        0.131086   0.188886   3.883629   3.589100   0.434000     0.035534
# min        0.236000   0.056500   0.000000 -22.895000   0.000000     0.027300
# 25%        0.395000   0.256000   1.000000 -12.111000   1.000000     0.030700
# 50%        0.508000   0.380000   5.000000  -9.883000   1.000000     0.035500
# 75%        0.592000   0.528000   9.000000  -7.376000   1.000000     0.042900
# max        0.771000   0.835000  11.000000  -5.303000   1.000000     0.252000
#
#        acousticness  instrumentalness   liveness    valence       tempo  \
# count      73.00000         73.000000  73.000000  73.000000   73.000000
# mean        0.61989          0.079008   0.137640   0.271527  120.643082
# std         0.30438          0.164879   0.082138   0.135744   31.683731
# min         0.00239          0.000000   0.055900   0.038400   70.060000
# 25%         0.39200          0.000006   0.099200   0.178000   94.023000
# 50%         0.70700          0.000307   0.114000   0.237000  124.026000
# 75%         0.88500          0.065100   0.127000   0.339000  143.979000
# max         0.98300          0.739000   0.531000   0.646000  180.917000
#
#          duration_ms  time_signature
# count      73.000000       73.000000
# mean   242604.808219        3.904110
# std     49974.674325        0.531361
# min    147952.000000        1.000000
# 25%    208653.000000        4.000000
# 50%    242014.000000        4.000000
# 75%    271387.000000        4.000000
# max    401426.000000        5.000000

# %%
test_playlist_audio_features.describe()
# Out:
#        danceability      energy         key    loudness        mode  \
# count    400.000000  400.000000  400.000000  400.000000  400.000000
# mean       0.538515    0.498890    5.217500   -9.950297    0.642500
# std        0.177702    0.269094    3.528643    5.891676    0.479864
# min        0.062500    0.006180    0.000000  -31.855000    0.000000
# 25%        0.416750    0.272750    2.000000  -12.463750    0.000000
# 50%        0.552500    0.480500    5.000000   -8.856500    1.000000
# 75%        0.670250    0.714750    8.000000   -5.923750    1.000000
# max        0.908000    0.995000   11.000000    0.496000    1.000000
#
#        speechiness  acousticness  instrumentalness    liveness     valence  \
# count   400.000000    400.000000        400.000000  400.000000  400.000000
# mean      0.088902      0.476746          0.155587    0.170617    0.346262
# std       0.112306      0.367008          0.293239    0.137960    0.234744
# min       0.025300      0.000122          0.000000    0.032800    0.029900
# 25%       0.033975      0.103000          0.000003    0.095500    0.159750
# 50%       0.042350      0.469500          0.001385    0.114500    0.289000
# 75%       0.080200      0.854000          0.129000    0.175000    0.502000
# max       0.947000      0.996000          0.967000    0.828000    0.963000
#
#             tempo    duration_ms  time_signature
# count  400.000000     400.000000      400.000000
# mean   117.794573  232668.337500        3.855000
# std     32.612584   70513.380462        0.514428
# min     44.109000   22747.000000        1.000000
# 25%     89.972500  192378.500000        4.000000
# 50%    115.348000  231094.500000        4.000000
# 75%    139.859750  269986.500000        4.000000
# max    214.527000  676545.000000        5.000000

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# #### Using Speechiness

# %% [markdown]
# We want to recommend songs that have the closest Speechiness to 0.045911 (the mean of whale dataset)

# %%
mean_speechiness = 0.045911

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# We can then loop through our test dataset and find the 5 closest values to the mean_speechiness

# %%
# Prevent it recommending songs I have listened to (this is personal preference!)
test_playlist = test_playlist_audio_features[73:]



recommended_songs = test_playlist.iloc[(
    test_playlist['speechiness'] - mean_speechiness)
    .abs()
    .argsort()
    [:5]]

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/0T7aTl1t15HKHfwep4nANV?utm_source=generator" width="100%" height="152" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>
# <br>
# <br>
# <br>
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/69Fm9O838y94hhkxWsJkoY?utm_source=generator" width="100%" height="152" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>
# <br>
# <br>
# <br>
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/354Cv7huFJnlEdVAHvhH3Q?utm_source=generator" width="100%" height="152" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>
# <br>
# <br>
# <br>
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/76BfKpZqnuNCZtbN8N3s4C?utm_source=generator" width="100%" height="152" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>
# <br>
# <br>
# <br>
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/1ZauqNrrbC4pYMwMtA2S27?utm_source=generator" width="100%" height="152" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
#
# <hr>
#
# ### Step 4) Using All Metrics
#
#
# We have shown that speechiness is not enough to define our music taste, so we need to create a bit more of an advanced recommendation system.
#
# <iframe src="https://giphy.com/embed/lrc1TZHRYxj7lGM3Vg" width="480" height="270" frameBorder="0" class="giphy-embed" allowFullScreen></iframe>

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# We saw that we have lots of meta data on songs so lets use all of that!
#
# However now we need to calculate distance over lots of dimensions, this will require a bit more of an advanced equations

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# # In comes Greek Hero Euclid
# <br>
#
# <img src="./images/euclid.png"
#      alt="Euclid"
#      style="height:500px;"/>
#
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# ### Euclidean Distance
#
# <img src="./images/euclidean.png"
#      alt="Euclidean Distance"
#      style="height:150px;"/>
#
#
# This looks a lot more complicated than it is. (Its just pythag repeated across multiple dimensions)

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %%
import math

# List out the features we care about
columns_to_check = ["danceability", "energy", "loudness", "speechiness", "acousticness", "instrumentalness", "valence", "tempo"]


means = whale_audio_features[columns_to_check].mean()

test_playlist['distance_from_mean'] = test_playlist[columns_to_check].apply(lambda row: math.sqrt(sum((row - means)**2)),axis=1)

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# <br>
# <br>
# <br>
#
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/0V57cVCVlaU9vXIUBlQdg2?utm_source=generator" width="100%" height="152" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>
#
# <br>
# <br>
# <br>
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/3xSN9JH0u8QCa9AquF5XvV?utm_source=generator" width="100%" height="152" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>
# <br>
# <br>
# <br>
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/52pGXXhSsBPx3jOSxlU35N?utm_source=generator" width="100%" height="152" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>
#
# <br>
# <br>
# <br>
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/1KQsrNv2vEW7AXKTrFz0Ah?utm_source=generator" width="100%" height="152" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>
# <br>
# <br>
# <br>
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/0gEcmyKlIUoi3sHTFVO1bE?utm_source=generator" width="100%" height="152" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>
# <br>
# <br>
# <br>

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# <hr>
#
# ### Step 5) Normalising Each Metric
#
# Some of you might have noticed the problem.

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %%
whale_audio_features.describe()
# Out:
#        danceability     energy        key   loudness       mode  speechiness  \
# count     73.000000  73.000000  73.000000  73.000000  73.000000    73.000000
# mean       0.502274   0.398518   5.027397 -10.311479   0.753425     0.045911
# std        0.131086   0.188886   3.883629   3.589100   0.434000     0.035534
# min        0.236000   0.056500   0.000000 -22.895000   0.000000     0.027300
# 25%        0.395000   0.256000   1.000000 -12.111000   1.000000     0.030700
# 50%        0.508000   0.380000   5.000000  -9.883000   1.000000     0.035500
# 75%        0.592000   0.528000   9.000000  -7.376000   1.000000     0.042900
# max        0.771000   0.835000  11.000000  -5.303000   1.000000     0.252000
#
#        acousticness  instrumentalness   liveness    valence       tempo  \
# count      73.00000         73.000000  73.000000  73.000000   73.000000
# mean        0.61989          0.079008   0.137640   0.271527  120.643082
# std         0.30438          0.164879   0.082138   0.135744   31.683731
# min         0.00239          0.000000   0.055900   0.038400   70.060000
# 25%         0.39200          0.000006   0.099200   0.178000   94.023000
# 50%         0.70700          0.000307   0.114000   0.237000  124.026000
# 75%         0.88500          0.065100   0.127000   0.339000  143.979000
# max         0.98300          0.739000   0.531000   0.646000  180.917000
#
#          duration_ms  time_signature
# count      73.000000       73.000000
# mean   242604.808219        3.904110
# std     49974.674325        0.531361
# min    147952.000000        1.000000
# 25%    208653.000000        4.000000
# 50%    242014.000000        4.000000
# 75%    271387.000000        4.000000
# max    401426.000000        5.000000

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ### Updated code

# %%
means = whale_audio_features[columns_to_check].mean()
stds = test_playlist[columns_to_check].std()

test_playlist['distance_from_mean'] = test_playlist[columns_to_check].apply(lambda row: math.sqrt(sum(((row - means)/stds)**2)),axis=1)

# %%
test_playlist.sort_values("distance_from_mean").head(5)
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 166         0.459   0.472    8   -11.412     0       0.0479         0.583
# 157         0.607   0.405    9    -8.607     1       0.0265         0.539
# 81          0.596   0.544    0   -11.759     1       0.0362         0.604
# 139         0.528   0.416    9    -8.523     1       0.0305         0.691
# 144         0.556   0.261    4   -11.668     1       0.0289         0.797
#
#      instrumentalness  liveness  valence    tempo            type  \
# 166          0.000115    0.1110    0.246  139.847  audio_features
# 157          0.000007    0.2310    0.233  129.543  audio_features
# 81           0.017000    0.2620    0.262  115.022  audio_features
# 139          0.000276    0.0953    0.184   99.868  audio_features
# 144          0.016000    0.0893    0.219  110.841  audio_features
#
#                          id                                   uri  \
# 166  4XT9wAQ1malGGztBCmVX3m  spotify:track:4XT9wAQ1malGGztBCmVX3m
# 157  3ou9rSNUQnE7XYmJkUUIOc  spotify:track:3ou9rSNUQnE7XYmJkUUIOc
# 81   7x46YkKAwp3yZpaa72n5Mu  spotify:track:7x46YkKAwp3yZpaa72n5Mu
# 139  6hH2y9wgEjgsSeJuv7kfaU  spotify:track:6hH2y9wgEjgsSeJuv7kfaU
# 144  0bndF6tTweNXPjwpPL7Slt  spotify:track:0bndF6tTweNXPjwpPL7Slt
#
#                                             track_href  \
# 166  https://api.spotify.com/v1/tracks/4XT9wAQ1malG...
# 157  https://api.spotify.com/v1/tracks/3ou9rSNUQnE7...
# 81   https://api.spotify.com/v1/tracks/7x46YkKAwp3y...
# 139  https://api.spotify.com/v1/tracks/6hH2y9wgEjgs...
# 144  https://api.spotify.com/v1/tracks/0bndF6tTweNX...
#
#                                           analysis_url  duration_ms  \
# 166  https://api.spotify.com/v1/audio-analysis/4XT9...       204000
# 157  https://api.spotify.com/v1/audio-analysis/3ou9...       223040
# 81   https://api.spotify.com/v1/audio-analysis/7x46...       279000
# 139  https://api.spotify.com/v1/audio-analysis/6hH2...       152280
# 144  https://api.spotify.com/v1/audio-analysis/0bnd...       172500
#
#      time_signature  distance_from_mean
# 166               4            0.761995
# 157               4            0.791283
# 81                4            0.810795
# 139               5            0.862744
# 144               4            0.890410

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/4XT9wAQ1malGGztBCmVX3m?utm_source=generator" width="100%" height="152" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>
# <br>
# <br>
# <br>
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/3ou9rSNUQnE7XYmJkUUIOc?utm_source=generator" width="100%" height="152" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>
# <br>
# <br>
# <br>
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/7x46YkKAwp3yZpaa72n5Mu?utm_source=generator&theme=0" width="100%" height="152" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>
# <br>
# <br>
# <br>
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/6hH2y9wgEjgsSeJuv7kfaU?utm_source=generator&theme=0" width="100%" height="152" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>
# <br>
# <br>
# <br>
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/0bndF6tTweNXPjwpPL7Slt?utm_source=generator&theme=0" width="100%" height="152" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ### Voila you have a recommendation system as good as Spotify
#
#
# <iframe src="https://giphy.com/embed/1BFEEIo4h1BuTH8eqP" width="480" height="403" frameBorder="0" class="giphy-embed" allowFullScreen></iframe>
